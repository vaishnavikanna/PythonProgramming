# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import DBSCAN
from sklearn import metrics
from sklearn.datasets import make_blobs
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler




df = pd.read_csv('Country-Data.csv')
df_sample = df.copy(deep = True)
col_names = ['health','total_fer']

features = df_sample[col_names]

X = StandardScaler().fit_transform(logval_features.values)


db = DBSCAN(eps=0.6, min_samples=4).fit(features)
core_samples_mask = np.zeros_like(db.labels_, dtype=bool)
core_samples_mask[db.core_sample_indices_] = True
labels = db.labels_
print(df_sample.loc[58])
print("cluster: "+ str(labels[58]))
print(df_sample.loc[159])
print("cluster: "+ str(labels[159]))
print(df_sample.loc[7])
print("cluster: "+str(labels[7]))
print(df_sample.loc[34])
print("cluster: "+str(labels[34]))
print(df_sample.loc[28])
print("cluster: "+str(labels[28]))

print(np.unique(labels))
# Number of clusters in labels, ignoring noise if present.
no_clusters = len(np.unique(labels) )
no_noise = np.sum(np.array(labels) == -1, axis=0)

print("Estimated number of clusters: %d" % no_clusters)
print("Estimated number of noise points: %d" % no_noise)

unique_labels = set(labels)
colors = [plt.cm.Spectral(each) for each in np.linspace(0, 1, len(unique_labels))]
for k, col in zip(unique_labels, colors):
    if k == -1:
        # Black used for noise.
        col = [0, 0, 0, 1]

    class_member_mask = labels == k

    xy = X[class_member_mask & core_samples_mask]
    plt.plot(
        xy[:, 0],
        xy[:, 1],
        "o",
        markerfacecolor=tuple(col),
        markeredgecolor="k",
        markersize=14,
    )

    xy = X[class_member_mask & ~core_samples_mask]
    plt.plot(
        xy[:, 0],
        xy[:, 1],
        "o",
        markerfacecolor=tuple(col),
        markeredgecolor="k",
        markersize=6,
    )

plt.title("Estimated number of clusters: %d" % n_clusters_)
plt.show()
# Out:
# country       Germany
# child_mort        4.2
# exports          42.3
# health           11.6
# imports          37.1
# income          40400
# inflation       0.758
# life_expec       80.1
# total_fer        1.39
# gdpp            41800
# Name: 58, dtype: object
# cluster: 0
# country       United States
# child_mort              7.3
# exports                12.4
# health                 17.9
# imports                15.8
# income                49400
# inflation              1.22
# life_expec             78.7
# total_fer              1.93
# gdpp                  48400
# Name: 159, dtype: object
# cluster: -1
# country       Australia
# child_mort          4.8
# exports            19.8
# health             8.73
# imports            20.9
# income            41400
# inflation          1.16
# life_expec         82.0
# total_fer          1.93
# gdpp              51900
# Name: 7, dtype: object
# cluster: 0
# country       China
# child_mort     15.7
# exports        26.3
# ...
